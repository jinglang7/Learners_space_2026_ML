# %% [markdown]
# <a href="https://colab.research.google.com/github/jinglang7/Learners_space_2026_ML/blob/main/Copy_of_The_Unsinkable_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell to install required libraries and import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn makes matplotlib plots look prettier!

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ### Step 1: Load the Data
# Use `pandas` to read the CSV file from the provided URL.

# %%
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# TODO: use pd.read_csv() to load the data into a dataframe named 'df'
df = df = pd.read_csv(url)

# --- SANITY CHECK ---
assert 'df' in locals(), "Error: You didn't name your dataframe 'df'."
assert len(df) == 891, f"Error: Expected 891 rows, but got {len(df)}. Check your loading code."
print("✅ Data loaded perfectly! Move to the next step.")
df.head()
# Out:
# ✅ Data loaded perfectly! Move to the next step.
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Step 2: Clean the Data
# Real-world data is messy. Let's find out what is missing and fix it.

# %%
# TODO: Print out the sum of null values for every column
print(df.isnull().sum())

# TODO: The 'Age' column has missing values. Fill the missing ages with the median age of the passengers.
df['Age'] = df['Age'].fillna(df['Age'].median())

print("Missing values handled!")

# --- SANITY CHECK ---
assert df['Age'].isnull().sum() == 0, "Error: There are still missing values in the Age column!"
print("✅ Missing ages handled perfectly!")
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Missing values handled!
# ✅ Missing ages handled perfectly!

# %% [markdown]
# ### Step 3: Visualize
# Time to draw some graphs. Create at least 3 plots below.
# Ideas: Survival rate by Gender, Passenger Class vs Survival, or an Age distribution histogram.

# %%
sns.set_theme(style="whitegrid")

# TODO: Plot 1
# Plot 1: Age vs. Fare (Scatter Plot)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived', palette='coolwarm', alpha=0.7)
plt.title('Passenger Age vs. Ticket Fare', fontsize=14)
plt.xlabel('Age')
plt.ylabel('Fare Paid (£)')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

# TODO: Plot 2
# Plot 2: Age by Class and Survival (Box Plot)

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Pclass', y='Age', hue='Survived', palette='Set3')
plt.title('Age Distribution by Passenger Class', fontsize=14)
plt.xlabel('Passenger Class (1st, 2nd, 3rd)')
plt.ylabel('Age')
plt.legend(title='Survived', labels=['No', 'Yes'], loc='upper right')
plt.show()

# TODO: Plot 3
# Plot 3: Feature Correlation (Heatmap)

plt.figure(figsize=(8, 6))
# First, we must filter the dataframe to only include numbers (math doesn't work on text)
numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
plt.title('Titanic Feature Correlation Heatmap', fontsize=14)
plt.show()
